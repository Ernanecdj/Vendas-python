# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernanecdj/Vendas-python/blob/main/Curso_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Passo a Passo de solução do Desafio

# %%
# Logica de programação

# passo 1 - percorrer todos os arquivos da pasta base de dados (pasta vendas)
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Colab Notebooks/Vendas")

tabela_total = pd.DataFrame()

# passo 2 - importar as bases de dados de vendas
for arquivo in lista_arquivo:
  if "Vendas" in arquivo:
    tabela = pd.read_csv(f"/content/drive/MyDrive/Colab Notebooks/Vendas/{arquivo}")
    tabela_total = pd.concat([tabela_total, tabela], ignore_index = True)

# passo 3 - tratar / compilar as bases de dados
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 9994        9910  HL1148      Câmera                   4        Norman
# 9995        9927  HL2714      Tablet                   2        Marina
# 9996        9932  HL1918      iPhone                   1          José
# 9997        9942  HL4379   Televisão                   1      Fernanda
# 9998        9978  HL8851    Notebook                   2       Mariane
#
#       Sobrenome        Data            Loja  Preco Unitario  Unnamed: 8
# ...

# %%
# passo 4 - calcular o produto mais vendido (em quantidade)
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida", "Preco Unitario"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %%
# passo 5 - calcular o produto que mais faturou (em faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# passo 6 - calcular a loja/cidade que mais vendeu (em faturamento)
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
tabela_lojas = tabela_lojas[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# São Paulo          22098300
# Rio de Janeiro     14867800
# Fortaleza          14087900
# Salvador           13111300
# Goiás               7441800
# Recife              7303000
# Curitiba            7060500
# Porto Alegre        6868600
# Belo Horizonte      6480300

# %%
import plotly.express as px
grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show
# Out:
# <bound method BaseFigure.show of Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'Loja=%{x}<br>Faturamento=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['São Paulo', 'Rio de Janeiro', 'Fortaleza', 'Salvador', 'Goiás',
#                           'Recife', 'Curitiba', 'Porto Alegre', 'Belo Horizonte'], dtype=object),
#               'xaxis': 'x',
#               'y': array([22098300, 14867800, 14087900, 13111300,  7441800,  7303000,  7060500,
#                            6868600,  6480300]),
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
# ...
